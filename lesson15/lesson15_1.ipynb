# %%
#下載JSON的文字檔,json==>複雜的表格資料結構
import requests 
url = 'https://opendata.cwa.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'

response = requests.get(url,verify=False) #verify=驗証,=False,全部不驗証
if response.ok:  #response.ok==>回應下載狀況
    print("下載成功")
    json_str:str = response.text
else:
    print("下載失敗")
# Out:
# 下載成功
# /home/vscode/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.cwa.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
#解析json成為python的資料結構
import json
jsonData = json.loads(json_str)
jsonData
# Out:
# {'success': 'true',
#  'result': {'resource_id': 'F-C0032-001',
#   'fields': [{'id': 'datasetDescription', 'type': 'String'},
#    {'id': 'locationName', 'type': 'String'},
#    {'id': 'parameterName', 'type': 'String'},
#    {'id': 'parameterValue', 'type': 'String'},
#    {'id': 'parameterUnit', 'type': 'String'},
#    {'id': 'startTime', 'type': 'Timestamp'},
#    {'id': 'endTime', 'type': 'Timestamp'}]},
#  'records': {'datasetDescription': '三十六小時天氣預報',
#   'location': [{'locationName': '嘉義縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫陣雨', 'parameterValue': '9'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '新北市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫陣雨', 'parameterValue': '9'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '嘉義市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫陣雨', 'parameterValue': '9'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '31', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '27', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '新竹縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰短暫陣雨', 'parameterValue': '11'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '新竹市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰短暫陣雨', 'parameterValue': '11'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺北市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫陣雨', 'parameterValue': '9'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺南市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '27', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '宜蘭縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '苗栗縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '雲林縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫陣雨', 'parameterValue': '9'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '花蓮縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺中市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '29', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺東縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '27', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '桃園市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰時多雲短暫陣雨', 'parameterValue': '10'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '南投縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰時多雲短暫陣雨', 'parameterValue': '10'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '27', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '高雄市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '金門縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '屏東縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '31', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '基隆市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫陣雨', 'parameterValue': '9'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '澎湖縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '彰化縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '連江縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '17', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '17', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '17', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '稍有寒意至舒適'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '稍有寒意'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-05-13 18:00:00',
#         'endTime': '2024-05-14 06:00:00',
#         'parameter': {'parameterName': '18', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 06:00:00',
#         'endTime': '2024-05-14 18:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-05-14 18:00:00',
#         'endTime': '2024-05-15 06:00:00',
#         'parameter': {'parameterName': '19', 'parameterUnit': 'C'}}]}]}]}}

# %%
#由response實體方法json(),直接轉換為python的資料結構
jsonData1 = response.json()
jsonData1['success']
jsonData1['records']['datasetDescription']
jsonRecords = jsonData1['records']['location']

# %%
weather_list:list[dict] = []
for item in jsonRecords:
    city_item:dict = {}
    city_item['城市'] = item['locationName']
    city_item['起始時間'] = item['weatherElement'][0]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][0]['time'][0]['endTime']
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['最高溫度'] = float(item['weatherElement'][4]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list
# Out:
# [{'城市': '嘉義縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 31.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新北市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 32.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '嘉義市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 32.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新竹縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 30.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新竹市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 29.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺北市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 33.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺南市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 25.0,
#   '最高溫度': 31.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '宜蘭縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 30.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '苗栗縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 30.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '雲林縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 32.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '花蓮縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 30.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺中市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 32.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺東縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 25.0,
#   '最高溫度': 32.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '桃園市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 31.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '南投縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 32.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '高雄市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 26.0,
#   '最高溫度': 32.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '金門縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 28.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '屏東縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 25.0,
#   '最高溫度': 34.0,
#   '感覺': '舒適至易中暑'},
#  {'城市': '基隆市',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 31.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '澎湖縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 28.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '彰化縣',
#   '起始時間': '2024-05-12 06:00:00',
#   '結束時間': '2024-05-12 18:00:00',
#   '最低溫度':