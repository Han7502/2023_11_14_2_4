# %%
import pandas as pd
#選取需要的欄和列
dataFrame1 = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame1.columns = ['統計年','區域別','年底人口數','土地面積','人口密度']
dataFrame2 = dataFrame1.drop(index=0)
dataFrame3 = dataFrame2.reindex(index=range(1,371))
dataFrame3
# Out:
#      統計年     區域別   年底人口數     土地面積    人口密度
# 1    111  新北市板橋區  549572  23.1373  23753
# 2    111  新北市三重區  379825   16.317  23278
# 3    111  新北市中和區  403109   20.144  20011
# 4    111  新北市永和區  212170   5.7138  37133
# 5    111  新北市新莊區  419966  19.7383  21277
# ..   ...     ...     ...      ...     ...
# 366  111  連江縣北竿鄉    3181      9.9    321
# 367  111  連江縣莒光鄉    1471      4.7    313
# 368  111  連江縣東引鄉    1534      3.8    404
# 369  111    東沙群島      …      2.38      …
# 370  111    南沙群島      …    0.5045      …
#
# [370 rows x 5 columns]

# %%
#value的檢查,有沒有空的欄位,資料類型
#info
dataFrame3.info()
#object代表的是字串,無法做數學運算
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    object
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    object
# dtypes: object(5)
# memory usage: 14.6+ KB

# %%
def toInt(value:str) -> int:
    try:
        newValue = int(value)
    except:
        newValue = 0
    return newValue
    #print(newValue)

def toFloat(value:str) -> float:
    try:
        newValue = float(value)
    except:
        newValue = 0.0
    return newValue

dataFrame3['年底人口數'] = dataFrame3['年底人口數'].map(toInt)
dataFrame3['人口密度'] = dataFrame3['人口密度'].map(toInt)
dataFrame3['土地面積'] = dataFrame3['土地面積'].map(toFloat)
#利用map及迴圈將值(字串str)轉成整數(Int),浮點數(Float)
dataFrame3.info()
dataFrame3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    int64
#  3   土地面積    370 non-null    float64
#  4   人口密度    370 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 14.6+ KB
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    111  新北市板橋區  549572  23.1373  23753
# 2    111  新北市三重區  379825  16.3170  23278
# 3    111  新北市中和區  403109  20.1440  20011
# 4    111  新北市永和區  212170   5.7138  37133
# 5    111  新北市新莊區  419966  19.7383  21277
# ..   ...     ...     ...      ...    ...
# 366  111  連江縣北竿鄉    3181   9.9000    321
# 367  111  連江縣莒光鄉    1471   4.7000    313
# 368  111  連江縣東引鄉    1534   3.8000    404
# 369  111    東沙群島       0   2.3800      0
# 370  111    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %%
#subscript[slice]
dataFrame4 = dataFrame3.iloc[:5]#取前5筆資料
#使用比較運算子
dataFrame4['年底人口數'] > 400000
#使用subscript[[bool]]
dataFrame4[dataFrame4['年底人口數'] > 400000]
# Out:
#    統計年     區域別   年底人口數     土地面積   人口密度
# 1  111  新北市板橋區  549572  23.1373  23753
