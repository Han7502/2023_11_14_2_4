# %%
import pandas as pd
#將csv直接轉換成dataframe
dataFrame1 = pd.read_csv('各鄉鎮市區人口密度.csv')
#改變欄位名稱
dataFrame1.columns = ['統計年','區域別','年底人口數','土地面積','人口密度']
dataFrame2 = dataFrame1.drop(index=0)
dataFrame3 = dataFrame2.reindex(index=range(1,371))
dataFrame4 = dataFrame3.reindex(columns=['區域別','年底人口數','土地面積','人口密度'])
dataFrame4
# Out:
#         區域別   年底人口數     土地面積    人口密度
# 1    新北市板橋區  549572  23.1373  23753
# 2    新北市三重區  379825   16.317  23278
# 3    新北市中和區  403109   20.144  20011
# 4    新北市永和區  212170   5.7138  37133
# 5    新北市新莊區  419966  19.7383  21277
# ..      ...     ...      ...     ...
# 366  連江縣北竿鄉    3181      9.9    321
# 367  連江縣莒光鄉    1471      4.7    313
# 368  連江縣東引鄉    1534      3.8    404
# 369    東沙群島      …      2.38      …
# 370    南沙群島      …    0.5045      …
#
# [370 rows x 4 columns]
