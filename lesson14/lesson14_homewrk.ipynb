# %%
#下載個股成交資訊.csv
#使用DataFrame顯示下載的資料
import requests
import csv
import pandas as pd
url = 'https://github.com/Han7502/2023_11_14_2_4/blob/main/lesson14/%E5%80%8B%E8%82%A1%E4%BA%A4%E6%98%93%E8%B3%87%E8%A8%8A.csv'
response:requests.Response = requests.get(url)
if response.status_code == 200:
    print("下載成功")
    data:str = response.text 
elif response.status_codes >= 400:
    print("下載失敗")
elif response.status_codes > 200:
    print("下載有問題")   

with open('個股交易資訊', mode = 'w', encoding='utf-8',newline='') as file:
    file.write(data)

with open('個股交易資訊', mode = 'r', encoding='utf-8',newline='') as file:
    dict_reader = csv.DictReader(file)
    csv_data:list[dict] = list(dict_reader)

csv_data
#dataFrame = pd.DataFrame(csv_data)
#dataFrame
# Out:
# 下載成功
# [{None: ['<!DOCTYPE html>']},
#  {None: ['<html']},
#  {None: ['  lang="en"']},
#  {None: ['  ']},
#  {None: ['  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"']},
#  {None: ['  data-a11y-animated-images="system" data-a11y-link-underlines="true"']},
#  {None: ['  >']},
#  {None: ['  <head>']},
#  {None: ['    <meta charset="utf-8">']},
#  {None: ['  <link rel="dns-prefetch" href="https://github.githubassets.com">']},
#  {None: ['  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">']},
#  {None: ['  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">']},
#  {None: ['  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">']},
#  {None: ['  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>']},
#  {None: ['  <link rel="preconnect" href="https://avatars.githubusercontent.com">']},
#  {None: ['  ']},
# ...

# %%
with open('個股交易資訊', mode = 'w', encoding='utf-8',newline='') as file:
    file.write(data)
